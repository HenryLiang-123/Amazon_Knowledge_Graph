# %%
# Import necessary libraries
from neo4j import GraphDatabase

# Configuration parameters
uri = "neo4j+s://28e5b287.databases.neo4j.io"
username = "neo4j"
password = "z9J3DPCCxGYELn99XDdFbFIBnWOwR5fdn4MiG_Nvdck"

# Create a database driver
driver = GraphDatabase.driver(uri, auth=(username, password))

# Session function
def run_query(query):
    with driver.session() as session:
        return list(session.run(query))

# Example Query: Fetch and print the first 10 nodes from the database
query = '''
MATCH (n1:Node)-[:CONNECTS]->(n2:Node)
RETURN 'Node ' + n1.id + ' connects to Node ' + n2.id
'''
results = run_query(query)
context_str = ""
for record in results:
    context_str += str(record[0]) + ", "
# Close the driver connection
driver.close()

# %%
# provide multiple samples about graph and labels in terms of nodes and arcs
system_prompt = """
You are an assistant that answers questions about a graph.
The latest prompt contains information about the graph in the form of a context string,
where each line represents 1 relationship between 2 nodes.
An example about the graph context looks like: 

Node 6939 connects to Node 50300. In this case, it means that there is a directed path from Node with id = 6939 to Node with id = 50300.

Also note that, in the context string provided, there may be Nodes where there are no outbound edges.
You need to generate a human readable response based on the given information.
Make the answer sound as a response to the question.
"""
# context = 'A is connected to D with a cost of 100, A is connected to C with a cost of 50, A is connected to B with a cost of 50, B is connected to D with a cost of 40, C is connected to E with a cost of 80, C is connected to D with a cost of 40, D is connected to A with a cost of 69, D is connected to F with a cost of 80, D is connected to E with a cost of 30, E is connected to F with a cost of 40'
context = context_str

def generate_user_prompt(question, context):
   return f"""
   The question is {question}
   Answer the question by using the provided information about the graph:
   {context}
   """

# %%
def response_formatter(s):
    return s.replace(", ", ",\n")

# %%
import openai

def get_gpt4_response(system_prompt, prompt, context, api_key, model="gpt-4-1106-preview"):
    """
    Send a request to the OpenAI Chat API and get a response from the model.
    
    Args:
        prompt (str): The user's question.
        context (str): Contextual information to be passed to the model.
        api_key (str): Your OpenAI API key.
        model (str): The model version to use.
    
    Returns:
        str: The model's response.
    """
    
    # Create the full prompt by combining the system prompt, context, and the user question
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": generate_user_prompt(prompt, context)}
    ]
    
    # Use the OpenAI Python client to send the request
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages
    )
    
    # Extract the response text and return
    return response.choices[0].message['content']

# You will need to install the openai Python package to use this function and also have a valid API key.

# %%
# Define your API key (keep it secret!)
openai.api_key = "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"
API_KEY = "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"

# %%
print(response_formatter(context))
# Out:
# Node 3356 connects to Node 45896,
# Node 3356 connects to Node 3549,
# Node 3356 connects to Node 29608,
# Node 3356 connects to Node 22652,
# Node 3356 connects to Node 3257,
# Node 3356 connects to Node 7018,
# Node 3356 connects to Node 1836,
# Node 6830 connects to Node 8758,
# Node 6939 connects to Node 45896,
# Node 6939 connects to Node 8758,
# Node 6939 connects to Node 4844,
# Node 6939 connects to Node 57821,
# Node 6939 connects to Node 29608,
# Node 6939 connects to Node 22652,
# Node 6939 connects to Node 57381,
# Node 6939 connects to Node 50300,
# Node 6939 connects to Node 1836,
# Node 6939 connects to Node 50304,
# Node 4826 connects to Node 45896,
# Node 4826 connects to Node 6939,
# Node 4826 connects to Node 2497,
# Node 4826 connects to Node 4608,
# Node 4826 connects to Node 1299,
# Node 4826 connects to Node 3257,
# Node 38803 connects to Node 4826,
# Node 38803 connects to Node 1221,
# Node 56203 connects to Node 38803,
# Node 2497 connects to Node 4777,
# ...

# %%
# Nodes
question = "How many unique nodes does the graph have, and what are they?"
context_info = context
response = get_gpt4_response(system_prompt, question, context_info, API_KEY, model = "gpt-4-1106-preview")
print(response_formatter(response))
# Out:
# Based on the information provided,
# the unique nodes in the graph are identified by their distinct numeric ids,
# and connections between them indicate directed paths from one node to another. After evaluating the context string,
# I've identified the following unique nodes within the graph:
#
# 1. 3356
# 2. 45896
# 3. 3549
# 4. 29608
# 5. 22652
# 6. 3257
# 7. 7018
# 8. 1836
# 9. 6830
# 10. 8758
# 11. 6939
# 12. 4844
# 13. 57821
# 14. 57381
# 15. 50300
# 16. 50304
# 17. 4826
# 18. 2497
# 19. 4608
# 20. 1299
# 21. 38803
# 22. 1221
# 23. 56203
# 24. 4777
# 25. 37989
# 26. 3333
# 27. 12586
# 28. 2516
# 29. 209
# 30. 1273
# 31. 4637
# 32. 10026
# 33. 2519
# 34. 7670
# 35. 18144
# 36. 38040
# 37. 6762
# 38. 2914
# 39. 8220
# 40. 1103
# 41. 42708
# 42. 9737
# 43. 6453
# 44. 4713
# 45. 174
# 46. 4651
# 47. 4766
# 48. 31025
# 49. 1136
# 50. 23969
#
# In total,
# there are 50 unique nodes in the graph.

# %%
# Nodes
question = "How many arcs does the graph have?"
context_info = context
response = get_gpt4_response(system_prompt, question, context_info, API_KEY, model = "gpt-4-1106-preview")
print(response_formatter(response))
# Out:
# The graph contains a total of 98 arcs. Each line in the graph context provided represents one arc between two nodes,
# and there are 98 lines of connections mentioned.

# %%
test = []
for record in results:
    test.append(str(record[0]))

len(test)
# Out:
# 100
